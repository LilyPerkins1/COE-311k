# %%
import numpy as np
import random
import matplotlib.pyplot as plt

# Data points
X = np.array([1, 2, 3, 4, 5])
Y = np.array([1.2, 2.8, 3.6, 4.5, 5.1])
# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([X, np.ones(len(X))]).T
# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]

print("X: ", X)
print("Y: ", Y)
print("A: ", A)

function = m*X + c
plt.scatter(X,Y, color = "red")
plt.plot(X, function, color = "black")
print(f"Slope: {m}, Intercept: {c}")
# Out:
# X:  [1 2 3 4 5]
# Y:  [1.2 2.8 3.6 4.5 5.1]
# A:  [[1. 1.]
#  [2. 1.]
#  [3. 1.]
#  [4. 1.]
#  [5. 1.]]
# Slope: 0.9500000000000001, Intercept: 0.5900000000000001

# %%
#randomized values

import numpy as np
import random
list_length = 10

X = np.array([random.uniform(0,10) for _ in range(list_length)])
Y = np.array([random.uniform(0,10) for _ in range(list_length)])

X.sort()
# Data points
# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([X, np.ones(len(X))]).T
# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]

print("X: ", X)
print("Y: ", Y)
print("A: ", A)

function = m*X + c
plt.scatter(X,Y, color = "red")
plt.plot(X, function, color = "black")
print(f"Slope: {m}, Intercept: {c}")
# Out:
# X:  [0.03836876 0.72091084 0.81074592 1.12552037 1.38800973 3.30843311
#  3.71922505 7.75951398 7.9141174  9.91464203]
# Y:  [3.56959174 7.04949299 5.55179937 1.02077479 2.68513052 6.40633481
#  3.87934542 6.63217477 4.46150889 8.55243279]
# A:  [[0.03836876 1.        ]
#  [0.72091084 1.        ]
#  [0.81074592 1.        ]
#  [1.12552037 1.        ]
#  [1.38800973 1.        ]
#  [3.30843311 1.        ]
#  [3.71922505 1.        ]
#  [7.75951398 1.        ]
#  [7.9141174  1.        ]
#  [9.91464203 1.        ]]
# Slope: 0.33725746565468795, Intercept: 3.7431410043345523

# %%
#randomized values and perturbations numpy built in

import numpy as np
import random
list_length = 10
max_point = [0,0,0] #x,y,error
min_point = [0,0,11] #x,y,error

X = np.array([random.uniform(0,10) for _ in range(list_length)])
Y = np.array([random.uniform(0,10) for _ in range(list_length)])
X.sort()
# Data points
# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([X, np.ones(len(X))]).T
# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]

plt.scatter(X,Y, color = "red") #the data points
plt.plot(X, m*X + c, color ="black") #the basic line


for i in range (0,len(Y)):
    y_val = Y[i]
    Y[i] = y_val + random.uniform(-1,1) #add error
    
    
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
#finding the residuals between the data and the new function
for i in range (0,len(Y)):
    residual_error = abs((m*X[i] + c) - Y[i])    
    print(residual_error)
    if residual_error > max_point[2]:
        max_point[0] = i
        max_point[1] = m*X[i] + c
        max_point[2] = residual_error

    if residual_error < min_point[2]:
        min_point[0] = i
        min_point[1] = m*X[i] + c
        min_point[2] = residual_error

    plt.plot(X, m*X + c, color = "blue")


#find max min residuals
print("\n")
print("Max residual error: ", max_point[2], "  At: (", max_point[0], " , ", max_point[1], ")")
print("Min residual error: ", min_point[2], "  At: (", min_point[0], " , ", min_point[1], ")")
# Out:
# 2.286848379699307
# 2.8156772430782557
# 1.4641893461721418
# 1.4720494225463847
# 3.242085936847101
# 3.3641340075494286
# 2.8131621014685617
# 0.42173541521982205
# 3.7065106092435753
# 0.8862539616060428
#
#
# Max residual error:  3.7065106092435753   At: ( 8  ,  6.453916461370915 )
# Min residual error:  0.42173541521982205   At: ( 7  ,  6.3755470278656245 )

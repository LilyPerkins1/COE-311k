# %%
import numpy as np
import random
import matplotlib.pyplot as plt

# Data points
X = np.array([1, 2, 3, 4, 5])
Y = np.array([1.2, 2.8, 3.6, 4.5, 5.1])
# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([X, np.ones(len(X))]).T
# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]

print("X: ", X)
print("Y: ", Y)
print("A: ", A)

function = m*X + c
plt.scatter(X,Y, color = "red")
plt.plot(X, function, color = "black")
print(f"Slope: {m}, Intercept: {c}")
# Out:
# X:  [1 2 3 4 5]
# Y:  [1.2 2.8 3.6 4.5 5.1]
# A:  [[1. 1.]
#  [2. 1.]
#  [3. 1.]
#  [4. 1.]
#  [5. 1.]]
# Slope: 0.9500000000000001, Intercept: 0.5900000000000001

# %%
#randomized values

import numpy as np
import random
list_length = 10

X = np.array([random.uniform(0,10) for _ in range(list_length)])
Y = np.array([random.uniform(0,10) for _ in range(list_length)])

X.sort()
# Data points
# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([X, np.ones(len(X))]).T
# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]

print("X: ", X)
print("Y: ", Y)
print("A: ", A)

function = m*X + c
plt.scatter(X,Y, color = "red")
plt.plot(X, function, color = "black")
print(f"Slope: {m}, Intercept: {c}")
# Out:
# X:  [0.44479607 0.58165916 0.77570189 1.6011329  5.41617703 5.73551985
#  5.91392666 6.35172897 8.04091529 9.03902533]
# Y:  [7.57964784 0.72569015 2.48220937 5.18919029 5.91756555 4.88467394
#  5.32782403 1.14714564 2.90537247 9.50297785]
# A:  [[0.44479607 1.        ]
#  [0.58165916 1.        ]
#  [0.77570189 1.        ]
#  [1.6011329  1.        ]
#  [5.41617703 1.        ]
#  [5.73551985 1.        ]
#  [5.91392666 1.        ]
#  [6.35172897 1.        ]
#  [8.04091529 1.        ]
#  [9.03902533 1.        ]]
# Slope: 0.22857309109895327, Intercept: 3.5627805150970238

# %%
#randomized values and perturbations

import numpy as np
import random
list_length = 10

X = np.array([random.uniform(0,10) for _ in range(list_length)])
Y = np.array([random.uniform(0,10) for _ in range(list_length)])
X.sort()
# Data points
# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([X, np.ones(len(X))]).T
# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]

plt.scatter(X,Y, color = "red") #the data points
plt.plot(X, m*X + c, color ="black") #the basic line


for i in range (0,len(Y)):
    y_val = Y[i]
    Y[i] = y_val + random.uniform(-1,1) #add error


m, c = np.linalg.lstsq(A, Y, rcond=None)[0]


plt.plot(X, m*X + c, color = "blue")

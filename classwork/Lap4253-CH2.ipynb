# %%
Number = 2025
remainder = 0
remainders = []
ListLength = 0

while (Number > 0):
    remainder = Number % 2
    remainders.append(remainder)
    Number = (Number/2) - remainder
    ListLength =+ 1
i = ListLength

while (i > 0):
    print(remainders[i])
    i -= 1
# Out:
# 1.5

# %%
import numpy as np
import matplotlib.pyplot as plt

k = 1
h_values = [0.01, 0.02, 0.03, 0.05, 0.1, 0.2, 0.3, 0.5]

x_start = 0
x_end = 10
y_0 = 1.0
v_0 = 0.0

plt.figure(figsize=(10, 6))

for h in h_values:
    x_values = np.arange(x_start, x_end + h, h)
    y_values = np.zeros(len(x_values))
    v_values = np.zeros(len(x_values))

    y_values[0] = y_0
    v_values[0] = v_0

    for i in range(1, len(x_values)):
        y_values[i] = y_values[i-1] + h * v_values[i-1]
        v_values[i] = v_values[i-1] + h * (-k * y_values[i-1])

    plt.plot(x_values, y_values, label=f'h={h}')

plt.xlabel('x')
plt.ylabel('y(x)')
plt.title('Euler Method Stability Test')
plt.legend()
plt.grid(True)
plt.show()

print("when does it become unstable? Is it becoming unstable?")
print("The plot is truly becoming unstable around h = 0.1. \nAt this stage it is varying significantly from what the expected solution should be producing. ")
print("Play with the value of K, what are you seeing?")
print("As we adjust k, the curvature of the graph changes. As k decreases, the oscillatory motion decreases into a slope. However, as k increases, the oscillatory motion changes into mostly a flat line, but the expected solution lines are still trying to account for curvature.")
# Out:
# when does it become unstable? Is it becoming unstable?
# The plot is truly becoming unstable around h = 0.1.
# At this stage it is varying significantly from what the expected solution should be producing.
# Play with the value of K, what are you seeing?
# As we adjust k, the curvature of the graph changes. As k decreases, the oscillatory motion decreases into a slope. However,

# %%
k = 10.0
h = 0.01

x_start = 0
x_end = 10
y_0 = 1.0
v_0 = 0.0

plt.figure(figsize=(10, 6))


x_values = np.arange(x_start, x_end + h, h)
y_values = np.zeros(len(x_values))
v_values = np.zeros(len(x_values))

y_values[0] = y_0
v_values[0] = v_0

for i in range(1, len(x_values)):
    y_values[i] = y_values[i-1] + h * v_values[i-1]
    v_values[i] = v_values[i-1] + h * (-k * y_values[i-1])

plt.plot(x_values, y_values, label=f'h={h}')

plt.xlabel('x')
plt.ylabel('y(x)')
plt.title('Euler Method Stability Test')
plt.legend()
plt.grid(True)
plt.show()

print("Thoughts on whether Euler's Method can solve this with a larger h?")
print("With a larger h, the quick and even oscillations are lost as euler gradually builds up error. \nAt a smaller h, no problem. At a larger h, the slow effect of growing will just get more and more emphasized. ")
# Out:
# Thoughts on whether Euler's Method can solve this with a larger h?
# With a larger h, the quick and even oscillations are lost as euler gradually builds up error.
# At a smaller h, no problem. At a larger h, the slow effect of growing will just get more and more emphasized.

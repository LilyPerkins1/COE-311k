# %%
import numpy as np

A = np.array([[2,1],[1,1]])
B = np.array([[2,4],[1,2]])
print("A: ", np.linalg.det(A))
print("B: ", np.linalg.det(B))
# Out:
# A:  1.0
# B:  0.0

# %%
print("Inverse A: ", np.linalg.inv(A))
print("Inverse B: ", np.linalg.inv(B))
if(np.linalg.inv(B) != true):
    print("no inverse")
# Out:
# Inverse A:  [[ 1. -1.]
#  [-1.  2.]]
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-7-fba8385e9d9e> in <module>
#       1 print("Inverse A: ", np.linalg.inv(A))
# ----> 2 print("Inverse B: ", np.linalg.inv(B))
#       3 if(np.linalg.inv(B) != true):
#       4     print("no inverse")
#
# <__array_function__ internals> in inv(*args, **kwargs)
#
# /opt/conda/lib/python3.8/site-packages/numpy/linalg/linalg.py in inv(a)
#     549     signature = 'D->D' if isComplexType(t) else 'd->d'
#     550     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 551     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     552     return wrap(ainv.astype(result_t, copy=False))
#     553
#
# /opt/conda/lib/python3.8/site-packages/numpy/linalg/linalg.py in _raise_linalgerror_singular(err, flag)
#      95
#      96 def _raise_linalgerror_singular(err, flag):
# ---> 97     raise LinAlgError("Singular matrix")
#      98
#      99 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix

# %%
print("A: ")
print(f"A:{A}")
start_time = time.perf_counter()
kappa = np.linalg.cond(A,2)
end_time = time.perf_counter()
total_time = end_time - start_time
print(kappa)

#jacobi
import time 
import numpy as np
def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
# Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
        #print("X is: ", x)
    return x, max_iterations

# Example usage
A = np.array([[1, 	1], [1, 1.0001]])
b = np.array([1, 1.0001])
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 1000
              
start_time = time.perf_counter()
solution, iterations = jacobi(A, b, x0, tol, max_iterations)
end_time = time.perf_counter()
total_time = end_time - start_time

print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print("Time of execution: ")
print(f" {total_time:.5f}", "seconds")
print("\n")

#gauss-Seidel
#leads to faster convergence
import numpy as np
def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    
    for k in range(max_iterations):
        x_new = x.copy()
        for i in range(n):
            
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
        
# Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new

    return x, max_iterations

A = np.array([[1, 	1], [1, 1.0001]])
b = np.array([1, 1.0001])

x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 1000

start_time = time.perf_counter()
solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)
end_time = time.perf_counter()
total_time = end_time - start_time

print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print("Time of execution: ")
print(f" {total_time:.5f}", "seconds")
print("\n")

x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 1000
              
start_time = time.perf_counter()
solution, iterations = jacobi(A, b, x0, tol, max_iterations)
end_time = time.perf_counter()
total_time = end_time - start_time

print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print("Time of execution: ")
print(f" {total_time:.5f}", "seconds")
print("\n")
# Out:
# A:
# A:[[1.     1.    ]
#  [1.     1.0001]]
# 40002.00007491187
# Solution: [0.        0.0487682]
# Iterations: 1000
# Time of execution:
#  0.04801 seconds
#
#
# Solution: [0.90493243 0.09515806]
# Iterations: 1000
# Time of execution:
#  0.03207 seconds
#
#
# Solution: [0.        0.0487682]
# Iterations: 1000
# Time of execution:
#  0.02847 seconds

# %%
A = np.array([
	[0.582745, 0.48	, 0.10	, 0.  	, 0.  	], 
 [0.48	, 1.044129, 0.46	, 0.10	, 0.  	],
 [0.10	, 0.46	, 1.10431 , 0.44	, 0.10	],
 [0.  	, 0.10	, 0.44	, 0.963889, 0.42	],
 [0.  	, 0.  	, 0.10	, 0.42	, 0.522565]], dtype=float)
b = np.array([1.162745, 2.084129, 2.20431 , 1.923889, 1.042565], dtype=float)

print("A: ")
print(f"A:{A}")
start_time = time.perf_counter()
kappa = np.linalg.cond(A,2)
end_time = time.perf_counter()
total_time = end_time - start_time
print("kappa: ", kappa, "\n")


#jacobi
import time
import numpy as np
def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
# Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
        if i == 500:
            print("500th X is: ", x)
    return x, max_iterations

# Example usage
A = np.array([
	[0.582745, 0.48	, 0.10	, 0.  	, 0.  	], 
 [0.48	, 1.044129, 0.46	, 0.10	, 0.  	],
 [0.10	, 0.46	, 1.10431 , 0.44	, 0.10	],
 [0.  	, 0.10	, 0.44	, 0.963889, 0.42	],
 [0.  	, 0.  	, 0.10	, 0.42	, 0.522565]], dtype=float)
b = np.array([1.162745, 2.084129, 2.20431 , 1.923889, 1.042565], dtype=float)
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 1000
              
start_time = time.perf_counter()
solution, iterations = jacobi(A, b, x0, tol, max_iterations)
end_time = time.perf_counter()
total_time = end_time - start_time

print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print("Time of execution: ")
print(f" {total_time:.5f}", "seconds")
print("\n")

#gauss-Seidel
#leads to faster convergence
import numpy as np
def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    
    for k in range(max_iterations):
        x_new = x.copy()
        for i in range(n):
            
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
        
# Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new

    return x, max_iterations

A = np.array([
	[0.582745, 0.48	, 0.10	, 0.  	, 0.  	], 
 [0.48	, 1.044129, 0.46	, 0.10	, 0.  	],
 [0.10	, 0.46	, 1.10431 , 0.44	, 0.10	],
 [0.  	, 0.10	, 0.44	, 0.963889, 0.42	],
 [0.  	, 0.  	, 0.10	, 0.42	, 0.522565]], dtype=float)
b = np.array([1.162745, 2.084129, 2.20431 , 1.923889, 1.042565], dtype=float)
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 1000

start_time = time.perf_counter()
solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)
end_time = time.perf_counter()
total_time = end_time - start_time

print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print("Time of execution: ")
print(f" {total_time:.5f}", "seconds")
print("\n")
# Out:
# A:
# A:[[0.582745 0.48     0.1      0.       0.      ]
#  [0.48     1.044129 0.46     0.1      0.      ]
#  [0.1      0.46     1.10431  0.44     0.1     ]
#  [0.       0.1      0.44     0.963889 0.42    ]
#  [0.       0.       0.1      0.42     0.522565]]
# kappa:  8.067443024472189
#
# Solution: [0.9848677  0.98485984 0.98485878 0.98486297 0.98487321]
# Iterations: 1000
# Time of execution:
#  0.05659 seconds
#
#
# Solution: [0.99999926 1.00000045 0.99999989 0.99999997 1.00000005]
# Iterations: 20
# Time of execution:
#  0.00122 seconds

# %%
#Jacobi and Gauss-Seidel guess the solution
#jacobi creates equations for every variable, then solve it with a first
#guess, creating a second iteration. It thens solves it again with the new 
#values. It repeats this supplementing process until the iterations stop
#changing much. Find x variables, solve for x variable, sub in x variable, solve 
# Gauss-Seidel is similar, but it updates each variable as it finds it.
#Solves one equation, subs in one variable, solves the next equation
#

#jacobi
import numpy as np
def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
# Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
        print("X is: ", x)
    return x, max_iterations

# Example usage
A = np.array([[4, -1, 0, 0],
              [-1, 4, -1, 0],
              [0, -1, 4, -1],
              [0, 0, -1, 3]])
b = np.array([15, 10, 10, 10])
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100
solution, iterations = jacobi(A, b, x0, tol, max_iterations)
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
# Out:
# X is:  [3 2 2 3]
# X is:  [4 3 3 4]
# X is:  [4 4 4 4]
# Solution: [4 4 4 4]
# Iterations: 3

# %%
#gauss-Seidel
#leads to faster convergence
import numpy as np
def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    
    for k in range(max_iterations):
        x_new = x.copy()
        for i in range(n):
            
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
        
# Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
        print("X is: ", x)

    return x, max_iterations

# %%
A = np.array([[4, -1, 0, 0],
              [-1, 4, -1, 0],
              [0, -1, 4, -1],
              [0, 0, -1, 3]])
b = np.array([15, 10, 10, 10])
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100
solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
# Out:
# X is:  [3 3 3 4]
# X is:  [4 4 4 4]
# Solution: [4 4 4 4]
# Iterations: 2
